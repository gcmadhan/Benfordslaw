# %%
import pandas as pd

# %%
df = pd.read_excel('fraudulent 45.xlsx', converters={'Global Company Key':str})

# %%
fraud_com = df['Global Company Key'].unique()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 12 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Global Company Key                                  124 non-null    object
#  1   Data Date                                           124 non-null    datetime64[ns]
#  2   Data Year - Fiscal                                  122 non-null    float64
#  3   Industry Format                                     124 non-null    object
#  4   Level of Consolidation - Company Annual Descriptor  124 non-null    object
#  5   Population Source                                   124 non-null    object
#  6   Data Format                                         124 non-null    object
#  7   Ticker Symbol                                       124 non-null    object
# ...

# %%
len(fraud_com)
# Out:
# 36

# %%
df1= pd.read_excel('entire database.xl.xlsx',  converters={'Global Company Key':str})

# %%
df1.head()
# Out:
#   Global Company Key  Data Date  Data Year - Fiscal Industry Format  \
# 0             001004 2010-05-31              2009.0            INDL
# 1             001004 2011-05-31              2010.0            INDL
# 2             001004 2012-05-31              2011.0            INDL
# 3             001004 2013-05-31              2012.0            INDL
# 4             001004 2014-05-31              2013.0            INDL
#
#   Level of Consolidation - Company Annual Descriptor Population Source  \
# 0                                                  C                 D
# 1                                                  C                 D
# 2                                                  C                 D
# 3                                                  C                 D
# 4                                                  C                 D
#
#   Data Format Ticker Symbol ISO Currency Code  Assets - Total  \
# 0         STD           AIR               USD        1501.042
# ...

# %%
len(df1)
# Out:
# 152881

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152881 entries, 0 to 152880
# Data columns (total 12 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   Global Company Key                                  152881 non-null  object
#  1   Data Date                                           152881 non-null  datetime64[ns]
#  2   Data Year - Fiscal                                  152711 non-null  float64
#  3   Industry Format                                     152881 non-null  object
#  4   Level of Consolidation - Company Annual Descriptor  152881 non-null  object
#  5   Population Source                                   152881 non-null  object
#  6   Data Format                                         152881 non-null  object
#  7   Ticker Symbol                                       152773 non-null  object
# ...

# %%
non_fraud = df1[~df1['Global Company Key'].isin(fraud_com)]['Global Company Key'].unique()

# %%
with open("non_fraud.txt",'w') as txt_file:
    for line in non_fraud:
        txt_file.write(line+"\n")

# %%
df1.head()
# Out:
#   Global Company Key  Data Date  Data Year - Fiscal Industry Format  \
# 0             001004 2010-05-31              2009.0            INDL
# 1             001004 2011-05-31              2010.0            INDL
# 2             001004 2012-05-31              2011.0            INDL
# 3             001004 2013-05-31              2012.0            INDL
# 4             001004 2014-05-31              2013.0            INDL
#
#   Level of Consolidation - Company Annual Descriptor Population Source  \
# 0                                                  C                 D
# 1                                                  C                 D
# 2                                                  C                 D
# 3                                                  C                 D
# 4                                                  C                 D
#
#   Data Format Ticker Symbol ISO Currency Code  Assets - Total  \
# 0         STD           AIR               USD        1501.042
# ...

# %%
df2=df1[df1['Global Company Key'].isin(['001004'])]

# %%
data = df1[~df1['Global Company Key'].isin(fraud_com)]['Global Company Key'].unique()

# %%
import random
random.choice(data)
# Out:
# '038439'

# %%
import benfordslaw as bl
def benford_fun(feat):
    X = df1[df1['Global Company Key'].isin([feat])]['Assets - Total']
    bl.fit(X)
    print(bl.results['P'])
    bl.plot()

# %%
benford_fun('038439')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [55], line 1
# ----> 1 benford_fun('038439')
#
# Cell In [15], line 3, in benford_fun(feat)
#       1 def benford_fun(feat):
#       2     X = df1[df1['Global Company Key'].isin([feat])]['Assets - Total']
# ----> 3     bl.fit(X)
#       4     print(bl.results['P'])
#       5     bl.plot()
#
# NameError: name 'bl' is not defined

# %%
import benford as bf

# %%
def ben_law(feat):
    #print("Global company id :",feat)
    X = df1[df1['Global Company Key'].isin([feat])]['Assets - Total'].astype('float')
    #df=df1[df1['Global Company Key'].isin([feat])]
    #b1=bf.first_digits(X,digs=1,confidence=95,chi_square=True, KS=True, MAD=True, verbose=False)
    #print(b1)
    mad = bf.mad(X, test=1, verbose=False)
    #benf = bf.Benford((df,'Assets - Total'))
    #benf.F1D.report()
    return mad

# %%
a =[]
for i in data:
    mad = ben_law(i)
    if mad <0.006:
        a.append(i)
        print(mad)
# Out:
# C:\Users\F14EIYF\AppData\Roaming\Python\Python310\site-packages\benford\benford.py:759: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[DIGS[digs]] = (temp.ZN // 10 ** ((log10(temp.ZN).astype(
# C:\Users\F14EIYF\AppData\Roaming\Python\Python310\site-packages\benford\benford.py:759: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[DIGS[digs]] = (temp.ZN // 10 ** ((log10(temp.ZN).astype(
# ...
